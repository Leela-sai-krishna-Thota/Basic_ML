# %% [markdown]
# <a href="https://colab.research.google.com/github/Leela-sai-krishna-Thota/Basic_ML/blob/main/Copy_of_pandas.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Assignment2

# %% [markdown]
# 1. Create a Pandas DataFrame from the following dictionary:
# data = {
#  'Name': ['Alice', 'Bob', 'Carol'],
#  'Age': [24, 27, 22],
#  'Salary': [50000, 55000, 48000]
# }
# • Add a new column called Bonus which is 10% of the salary.

# %%
import pandas as pd

data = {
    'Name': ['Alice', 'Bob', 'Carol'],
    'Age': [24, 27, 22],
    'Salary': [50000, 55000, 48000]
}
df = pd.DataFrame(data)

df['Bonus'] = df['Salary'] * 0.10
df
# Out:
#     Name  Age  Salary   Bonus
# 0  Alice   24   50000  5000.0
# 1    Bob   27   55000  5500.0
# 2  Carol   22   48000  4800.0

# %% [markdown]
# . Given the DataFrame created in the above question
#
# • Display the first two rows.
# • Compute the mean salary.

# %%
df.head(2)
mean_salary = df['Salary'].mean()
print(mean_salary)
# Out:
# 58000.0

# %% [markdown]
# 3. Using the same DataFrame:
# • Extract all rows where the Age is greater than 25.
# • Filter out rows where the Salary is less than 50000.

# %%
df[df['Age'] > 25]
df[df['Salary'] >= 50000]
df
# Out:
#     Name  Age  Salary   Bonus
# 0  Alice   24   50000  5000.0
# 1    Bob   27   55000  5500.0
# 2  Carol   22   48000  4800.0

# %% [markdown]
# 4.Create the following DataFrame: data = { 'A': [1, 2, None, 4], 'B': [None, 2, 3, None], 'C': [1, 2, 3, 4] } df = pd.DataFrame(data) • Fill missing values in column A with the mean of the column. • Drop rows where all values are None.

# %%
import pandas as pd
data = {
 'A': [1, 2, None, 4],
 'B': [None, 2, 3, None],
 'C': [1, 2, 3, 4]
}
df = pd.DataFrame(data)
df['A'].fillna(df['A'].mean(), inplace=True)
df = df.dropna(how='all')
df
# Out:
# <ipython-input-6-fa040f542735>:8: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['A'].fillna(df['A'].mean(), inplace=True)
#           A    B  C
# 0  1.000000  NaN  1
# 1  2.000000  2.0  2
# 2  2.333333  3.0  3
# 3  4.000000  NaN  4

# %% [markdown]
# 5. Create a DataFrame for employees:
# data = {
#  'Department': ['HR', 'HR', 'IT', 'IT', 'Finance'],
#  'Employee': ['Alice', 'Bob', 'Carol', 'David', 'Eve'],
#  'Salary': [50000, 45000, 60000, 65000, 70000]
# }
# • Group the data by Department and compute the total and mean salary for each
# department.

# %%
import pandas as pd
data = {
 'Department': ['HR', 'HR', 'IT', 'IT', 'Finance'],
 'Employee': ['Alice', 'Bob', 'Carol', 'David', 'Eve'],
 'Salary': [50000, 45000, 60000, 65000, 70000]
}
df = pd.DataFrame(data)
department_stats = df.groupby('Department')['Salary'].agg(['sum', 'mean'])
department_stats
# Out:
#                sum     mean
# Department
# Finance      70000  70000.0
# HR           95000  47500.0
# IT          125000  62500.0

# %% [markdown]
# 6. Given two DataFrames:
# df1 = pd.DataFrame({'ID': [1, 2, 3], 'Name': ['Alice', 'Bob', 'Carol']})
# df2 = pd.DataFrame({'ID': [2, 3, 4], 'Age': [25, 30, 22]})
# • Perform an inner join on the ID column

# %%
import pandas as pd

df1 = pd.DataFrame({'ID': [1, 2, 3], 'Name': ['Alice', 'Bob', 'Carol']})
df2 = pd.DataFrame({'ID': [2, 3, 4], 'Age': [25, 30, 22]})

merged_df = pd.merge(df1, df2, on='ID', how='inner')
merged_df
# Out:
#    ID   Name  Age
# 0   2    Bob   25
# 1   3  Carol   30

# %% [markdown]
# 7. Given a small dataset, clean and display basic
#
# statistics using Pandas.

# %%
import pandas as pd
import numpy as np

# Create a sample dataset with some missing and inconsistent data
data = {
    'Name': ['Alice', 'Bob', 'Carol', 'David', 'Eve'],
    'Age': [25, 30, np.nan, 22, 28],
    'City': ['New York', 'London', 'Paris', 'london', 'Tokyo'],
    'Salary': [60000, 75000, np.nan, 55000, 65000]
}

df = pd.DataFrame(data)
print(df)
# Out:
#     Name   Age      City   Salary
# 0  Alice  25.0  New York  60000.0
# 1    Bob  30.0    London  75000.0
# 2  Carol   NaN     Paris      NaN
# 3  David  22.0    london  55000.0
# 4    Eve  28.0     Tokyo  65000.0

# %% [markdown]
# 8. small EDA task
# •
# Load the Titanic dataset (titanic.csv) into a Pandas DataFrame.
# •
# Perform the following tasks:
# o
# Display the number of missing values in each column.
# o
# Find the average age of passengers.
# o
# Create a bar plot to show the survival rate based on gender.

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Load the Titanic dataset
file_path = '"C:\Users\HP\Downloads\Titanic-Dataset.csv"'  # Replace with your actual file path
titanic_data = pd.read_csv(file_path)

# Display the number of missing values in each column
missing_values = titanic_data.isnull().sum()
print("Missing values in each column:")
print(missing_values)

# Find the average age of passengers
average_age = titanic_data['Age'].mean()
print("\nAverage age of passengers:", average_age)

# Create a bar plot to show the survival rate based on gender
survival_rate_gender = titanic_data.groupby('Sex')['Survived'].mean()
survival_rate_gender.plot(kind='bar', color=['skyblue', 'salmon'], title='Survival Rate by Gender')
plt.ylabel('Survival Rate')
plt.xlabel('Gender')
plt.xticks(rotation=0)
plt.show()
# Out:
#   File "<ipython-input-12-8d4d1f20aa6e>", line 5
#     file_path = '"C:\Users\HP\Downloads\Titanic-Dataset.csv"'  # Replace with your actual file path
#                                                                ^
# SyntaxError: (unicode error) 'unicodeescape' codec can't decode bytes in position 3-4: truncated \UXXXXXXXX escape

# %% [markdown]
# 9.Data Transformation
# •
# Load a dataset containing daily temperatures and dates. Perform the following:
# o
# Convert the date column into a DateTime object.
# o
# Create a new column that categorizes temperatures into High, Medium, or Low.

# %%
import pandas as pd

e.
try:
  df = pd.read_csv('temperature_data.csv')
except FileNotFoundError:
  print("Error: 'temperature_data.csv' not found. Please ensure the file exists in the current directory or provide the full path.")
  df = pd.DataFrame({'Date': ['2023-11-15', '2023-11-16', '2023-11-17'],
                     'Temperature': [25, 32, 18]})
  print("Using a sample DataFrame instead:")

df['Date'] = pd.to_datetime(df['Date'])

def categorize_temperature(temp):
    if temp >= 30:
        return 'High'
    elif temp >= 15:
        return 'Medium'
    else:
        return 'Low'

df['Temperature_Category'] = df['Temperature'].apply(categorize_temperature)

print(df)
# Out:
# Error: 'temperature_data.csv' not found. Please ensure the file exists in the current directory or provide the full path.
# Using a sample DataFrame instead:
#         Date  Temperature Temperature_Category
# 0 2023-11-15           25               Medium
# 1 2023-11-16           32                 High
# 2 2023-11-17           18               Medium
